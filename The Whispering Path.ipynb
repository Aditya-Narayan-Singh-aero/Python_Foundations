# %%
start = input("Do you wish to travel upon The Whispering Path?(yes/no): ").lower()
if start == "yes":
    
    name = input("What is your name, traveler?")
    weapon = input("Choose your weapon: Rusting Sword or Glowing Amulet.").lower()
    if weapon == "rusting sword" or weapon == "glowing amulet":
        weapon_choice = True
        print(name,"wakes up at the edge of the Whispering Woods holding a",weapon)

        print("You stand at the entrance of the forest. The path splits in two.")
        print("Option A: Take the overgrown, dark path to the left.")
        print("Option B: Take the wide, foggy path to the right.")        
        choice_1 = input("Which path would i like to take(A or B)?: ").lower()

        if choice_1 == "a":
            print("A massive, snarling shadow wolf blocks your path. It bares its fangs.")
            print("Option A: Stand your ground and attack the wolf.")
            print("Option B: Climb a nearby tree to hide.")
            choice_2_a = input("What would your do?(A or B): ").lower()

            if choice_2_a == "a":
                if weapon == "rusting sword":
                    print("You swing your sword. It chips on the wolf's shadow armor, but the strike frightens the beast away. You find a glowing chest behind it.")
                elif weapon == "glowing amulet":
                    print("You hold up the amulet. It flashes brightly, blinding the wolf, which runs into the bushes. You find a glowing chest where it stood.")
                print("Option A: Open the chest.")
                print("Option B: Leave it alone and walk past it.")
                choice_3_a = input("What would you do?(A or B): ").lower()

                if choice_3_a == "a":
                    print("The chest traps you! You are suddenly teleported into a hidden treasury filled with gold, but the doors are locked forever. You are rich, but trapped. [Game Over - Wealthy but Trapped Ending]")
                elif choice_3_a == "b":
                    print("You escape the danger, but you lose your way in the deep woods. After hours of walking, you find a peaceful hidden village of elves who welcome you as one of their own. You never find your way home, but you live a happy life. [Game Over - New Home Ending]")
                else:
                    print("Incorrect choice, play again!!")

            elif choice_2_a == "b":
                print("You scramble up the tree, but your weapon slips! It falls to the ground with a loud clang. The wolf looks up and starts scratching at the trunk, knocking you off balance.")
                print("Option A: Jump to a neighboring tree branch.")
                print("Option B: Dive out of the tree to grab your weapon.")
                choice_3_b = input("What would you do?(A or B): ").lower()

                if choice_3_b == "a":
                    print("You escape the danger, but you lose your way in the deep woods. After hours of walking, you find a peaceful hidden village of elves who welcome you as one of their own. You never find your way home, but you live a happy life. [Game Over - New Home Ending]")
                elif choice_3_b == "b":
                    print("The fall is too rough. You survive, but your weapon is destroyed and you are too exhausted to continue. You are forced to turn back and return to your village empty-handed. [Game Over - Defeat Ending]")
                else:
                    print("Incorrect choice, play again!!")

            else:
                    print("Incorrect choice, play again!!")

                
                    
        elif choice_1 == "b":
            print("The fog clears, revealing a crumbling stone bridge over a roaring river. A strange old man sits on the bridge, demanding a toll to pass.")
            print("Option A: Try to sneak past him underneath the bridge.")
            print("Option B: Talk to the man and ask what toll he wants.")
            choice_2_b = input("What would you do?(A or B): ").lower()

            if choice_2_b == "a":
                print("You climb down the slippery rocks. Your foot slips, and you catch yourself, but you are dangling over the rushing water.")
                print("Option A: Use all your strength to pull yourself back up.")
                print("Option B: Let go and trust the river current.")
                choice_4_a = input("What would you do?(A or B): ").lower()

                if choice_4_a == "a":
                    print("The fall is too rough. You survive, but your weapon is destroyed and you are too exhausted to continue. You are forced to turn back and return to your village empty-handed. [Game Over - Defeat Ending]")
                    
                elif choice_4_a == "b":
                    print("Your bravery wins the day. The river guides you safely to the other side of the forest, where you find the Lost City of Gold. Using your weapon, you claim your rightful place as the hero of the realm. [Game Over - True Victory Ending]")
                else:
                    print("Incorrect choice, play again!!")

            elif choice_2_b == "b":
                print("The old man smiles. I do not want gold, he says. I want a story. Tell me the name of the brave adventurer who stands before me.")
                print("Option A: Tell him your real name")
                print("Option B: Lie and give him a fake name.")

                choice_4_b =input("What would you do?(A or B): ").lower()
                if choice_4_b == "a":
                    print("Your honesty wins the day. The river/old man guides you safely to the other side of the forest, where you find the Lost City of Gold. Using your weapon, you claim your rightful place as the hero of the realm. [Game Over - True Victory Ending]")
                elif choice_4_b == "b":
                    print("The lie traps you! You are suddenly teleported into a hidden treasury filled with gold, but the doors are locked forever. You are rich, but trapped. [Game Over - Wealthy but Trapped Ending]")
                    
                else:
                    print("Incorrect choice, play again!!")
                    
            else:
                    print("Incorrect choice, play again!!")
            
            
        else:
                    print("Incorrect choice, play again!!")
    
    else:
        print("Kindly choose the appropriate weapon from the choices")
    
else:
    print("Come back when you are ready")
